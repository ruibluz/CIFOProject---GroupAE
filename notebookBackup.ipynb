# %% [markdown]
# <div style="display: flex; align-items: center; justify-content: center; flex-wrap: wrap;">
#     <div style="flex: 1; max-width: 400px; display: flex; justify-content: center;">
#         <img src="https://diretorio.bad.pt/wp-content/uploads/2015/09/55c9dc4270c60-IMS-rgb_logo.png" style="max-width: 50%; height: auto; margin-top: 50px; margin-bottom: 50px;margin-left: 6rem;">
#     </div>
#     <div style="flex: 2; text-align: center; margin-top: 20px;margin-left: 8rem;">
#         <div style="font-size: 28px; font-weight: bold; line-height: 1.2;">
#             <span style="color:rgb(190, 214, 47);">CIFO Project |</span> <span style="color:rgb(92, 102, 108);">Sports League: Optimization using Genetic Algorithms</span>
#         </div>
#         <div style="font-size: 17px; font-weight: bold; margin-top: 10px;">
#             Spring Semester | 2024 - 2025
#         </div>
#         <div style="font-size: 17px; font-weight: bold;">
#             Master in Data Science and Advanced Analytics
#         </div>
#         <div style="margin-top: 20px;">
#             <div>Diogo Duarte, 20240525</div>
#             <div>Rodrigo Sardinha, 20211627</div>
#             <div>Rui Luz, 20211628</div>
#         </div>
#         <div style="margin-top: 20px; font-weight: bold;">
#             Group AE
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right,rgb(190, 214, 47), rgb(92, 102, 108));
#             padding: 1px; color: white; border-radius: 500px; text-align: center;">
# </div>

# %% [markdown]
# # Imports

# %%
import pandas as pd

# import py files
from Classes import Player, Team, LeagueIndividual
from algorithms.GA_mutation import mutation_swap_players, mutation_regenerate_team, mutation_balance_teams
from algorithms.GA_crossover import team_crossover, position_crossover

# %% [markdown]
# # Local Data

# %%
df = pd.read_csv("data/players.csv")
df = df.drop(columns=['Unnamed: 0']) # drop the index column

# %% [markdown]
# # Problem Configuration

# %%
TEAM_SIZE = 7
NUM_TEAMS = 5
BUDGET_LIMIT = 750
TEAM_STRUCTURE = {"GK": 1, "DEF": 2, "MID": 2, "FWD": 2}
POPULATION_SIZE = 20

# %% [markdown]
# # Convert DF to player objects

# %%
players_by_position = {
    pos: [Player.from_dict(row) for _, row in df[df['Position'] == pos].iterrows()]
    for pos in TEAM_STRUCTURE
}

# %% [markdown]
# # Generate Population

# %%
# === GENERATE POPULATION ===
def generate_initial_population(size, players_by_position, team_structure, budget_limit, num_teams):
    population = []
    attempts = 0
    max_attempts = 1000 # avoid infinite loop if unable to generate valid leagues

    while len(population) < size and attempts < max_attempts:
        indiv = LeagueIndividual(players_by_position, team_structure, budget_limit, num_teams)
        if indiv.league is not None:
            population.append(indiv)
        attempts += 1

    return population

population = generate_initial_population(
    POPULATION_SIZE,
    players_by_position,
    TEAM_STRUCTURE,
    BUDGET_LIMIT, 
    NUM_TEAMS
)

# %%
# PRINT ENTIRE POPULATION
def print_population(population):
    for i, indiv in enumerate(population):
        print(f"\n🏟️ League {i+1} | 🧬 Fitness: {indiv.fitness:.4f}")
        all_names = set()
        for j, team in enumerate(indiv.league):
            names = [p.name for p in team.players]
            positions = [p.position for p in team.players]
            skill = team.avg_skill()
            salary = team.total_salary()
            print(f"  🏆 Team {j+1} | 🧍 Positions: {positions} | 📊 Avg Skill: {skill:.2f} | 💰 Salary: {salary}M")

            # Optional: check for duplicate players within individual
            duplicates = set(names).intersection(all_names)
            if duplicates:
                print(f"    ⚠️ Duplicate Players: {duplicates}")
            all_names.update(names)

# Example usage:
print_population(population)
# Out:
# 🏟️ League 1 | 🧬 Fitness: 1.0317
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.14 | 💰 Salary: 732M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.00 | 💰 Salary: 655M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.00 | 💰 Salary: 665M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.71 | 💰 Salary: 705M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.14 | 💰 Salary: 667M
#
# 🏟️ League 2 | 🧬 Fitness: 0.4815
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.29 | 💰 Salary: 697M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.86 | 💰 Salary: 700M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.14 | 💰 Salary: 660M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.43 | 💰 Salary: 672M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.29 | 💰 Salary: 695M
#
# 🏟️ League 3 | 🧬 Fitness: 0.7581
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.00 | 💰 Salary: 670M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.57 | 💰 Salary: 732M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.57 | 💰 Salary: 660M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.86 | 💰 Salary: 665M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.00 | 💰 Salary: 697M
#
# 🏟️ League 4 | 🧬 Fitness: 0.6602
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.71 | 💰 Salary: 690M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.29 | 💰 Salary: 685M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.43 | 💰 Salary: 730M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.14 | 💰 Salary: 687M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.43 | 💰 Salary: 632M
#
# 🏟️ League 5 | 🧬 Fitness: 1.0591
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.71 | 💰 Salary: 745M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.29 | 💰 Salary: 637M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.14 | 💰 Salary: 652M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.43 | 💰 Salary: 700M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.43 | 💰 Salary: 690M
#
# 🏟️ League 6 | 🧬 Fitness: 1.8547
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 84.57 | 💰 Salary: 627M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 83.86 | 💰 Salary: 605M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.86 | 💰 Salary: 725M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.57 | 💰 Salary: 742M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.14 | 💰 Salary: 725M
#
# 🏟️ League 7 | 🧬 Fitness: 0.9955
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.86 | 💰 Salary: 664M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.00 | 💰 Salary: 740M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.00 | 💰 Salary: 690M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.14 | 💰 Salary: 655M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.00 | 💰 Salary: 675M
#
# 🏟️ League 8 | 🧬 Fitness: 0.9748
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.14 | 💰 Salary: 669M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.00 | 💰 Salary: 650M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.57 | 💰 Salary: 715M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.43 | 💰 Salary: 715M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.86 | 💰 Salary: 675M
#
# 🏟️ League 9 | 🧬 Fitness: 1.6248
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.00 | 💰 Salary: 645M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.00 | 💰 Salary: 705M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 84.00 | 💰 Salary: 612M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.00 | 💰 Salary: 747M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.00 | 💰 Salary: 715M
#
# 🏟️ League 10 | 🧬 Fitness: 1.2434
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.00 | 💰 Salary: 675M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 84.43 | 💰 Salary: 620M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.43 | 💰 Salary: 722M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.00 | 💰 Salary: 740M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.14 | 💰 Salary: 667M
#
# 🏟️ League 11 | 🧬 Fitness: 0.7527
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.00 | 💰 Salary: 647M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.71 | 💰 Salary: 710M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.14 | 💰 Salary: 695M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.29 | 💰 Salary: 685M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.86 | 💰 Salary: 687M
#
# 🏟️ League 12 | 🧬 Fitness: 0.9873
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.29 | 💰 Salary: 665M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.29 | 💰 Salary: 669M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.43 | 💰 Salary: 640M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.86 | 💰 Salary: 735M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.14 | 💰 Salary: 715M
#
# 🏟️ League 13 | 🧬 Fitness: 1.3655
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.57 | 💰 Salary: 742M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.14 | 💰 Salary: 645M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 84.43 | 💰 Salary: 617M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.86 | 💰 Salary: 735M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.00 | 💰 Salary: 685M
#
# 🏟️ League 14 | 🧬 Fitness: 0.9187
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.00 | 💰 Salary: 737M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.00 | 💰 Salary: 675M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.00 | 💰 Salary: 670M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.29 | 💰 Salary: 650M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.71 | 💰 Salary: 692M
#
# 🏟️ League 15 | 🧬 Fitness: 0.9955
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.43 | 💰 Salary: 665M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.29 | 💰 Salary: 652M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.86 | 💰 Salary: 695M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.00 | 💰 Salary: 727M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.43 | 💰 Salary: 685M
#
# 🏟️ League 16 | 🧬 Fitness: 1.1829
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.57 | 💰 Salary: 692M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 84.86 | 💰 Salary: 640M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.29 | 💰 Salary: 702M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.29 | 💰 Salary: 655M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.00 | 💰 Salary: 735M
#
# 🏟️ League 17 | 🧬 Fitness: 0.6350
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.00 | 💰 Salary: 662M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.71 | 💰 Salary: 685M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.57 | 💰 Salary: 670M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.43 | 💰 Salary: 730M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.29 | 💰 Salary: 677M
#
# 🏟️ League 18 | 🧬 Fitness: 1.0552
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.14 | 💰 Salary: 662M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.57 | 💰 Salary: 730M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 84.57 | 💰 Salary: 620M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.29 | 💰 Salary: 727M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.43 | 💰 Salary: 685M
#
# 🏟️ League 19 | 🧬 Fitness: 0.8543
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.29 | 💰 Salary: 690M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.71 | 💰 Salary: 665M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.29 | 💰 Salary: 629M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.14 | 💰 Salary: 720M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 87.57 | 💰 Salary: 720M
#
# 🏟️ League 20 | 🧬 Fitness: 2.0049
#   🏆 Team 1 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 85.00 | 💰 Salary: 644M
#   🏆 Team 2 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 83.29 | 💰 Salary: 585M
#   🏆 Team 3 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.43 | 💰 Salary: 750M
#   🏆 Team 4 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 86.86 | 💰 Salary: 705M
#   🏆 Team 5 | 🧍 Positions: ['GK', 'DEF', 'DEF', 'MID', 'MID', 'FWD', 'FWD'] | 📊 Avg Skill: 88.43 | 💰 Salary: 740M

# %% [markdown]
# # Mutations

# %% [markdown]
# ## #1 Swap Players Betweeen Teams

# %%
individual = LeagueIndividual(players_by_position, TEAM_STRUCTURE, BUDGET_LIMIT, NUM_TEAMS)

# %%
swap_players = mutation_swap_players(individual)
print(swap_players)
# Out:
# <LeagueIndividual fitness=1.1514>

# %%
if swap_players == individual:
    print("⚠️  No mutation applied (swap failed after multiple attempts).")
else:
    print("✅ Mutation applied successfully.")
# Out:
# ✅ Mutation applied successfully.

# %% [markdown]
# ### Testing code mutation_swap_players

# %%
# test mutation_swap_players
 
def print_league_details(league_indiv, label=""):
    print(f"\n{'='*50}\n🏟️  {label} (Fitness: {league_indiv.fitness:.4f})\n{'='*50}")
    
    all_players = set()
    valid = True

    for i, team in enumerate(league_indiv.league):
        print(f"\n🏆 Team {i+1}")
        for player in team.players:
            print(f"  - {player}")
        avg = team.avg_skill()
        total_salary = team.total_salary()
        print(f"    📊 Avg Skill: {avg:.2f} | 💰 Total Salary: €{total_salary}M")
        
        all_players.update(player.name for player in team.players)

        if not team.is_valid(league_indiv.team_structure, league_indiv.budget_limit):
            print("    ❌ Invalid team (structure or budget)")
            valid = False

    expected_total = sum(league_indiv.team_structure.values()) * len(league_indiv.league)
    if len(all_players) != expected_total:
        print("⚠️  Duplicate players found across teams!")
        valid = False

    print(f"\n✅ Valid League: {valid}")
    return valid


mutated = mutation_swap_players(individual)

# # === PRINT RESULTS ===
print_league_details(individual, "Original League")
print_league_details(mutated, "Mutated League")
# Out:
# ==================================================
# 🏟️  Original League (Fitness: 1.1655)
# ==================================================
#
# 🏆 Team 1
#   - GK: Blake Henderson | Skill: 87 | Salary: €95M
#   - DEF: Owen Parker | Skill: 88 | Salary: €100M
#   - DEF: Jaxon Griffin | Skill: 79 | Salary: €65M
#   - MID: Gavin Richardson | Skill: 87 | Salary: €95M
#   - MID: Ashton Phillips | Skill: 90 | Salary: €110M
#   - FWD: Zachary Nelson | Skill: 86 | Salary: €92M
#   - FWD: Tyler Jenkins | Skill: 80 | Salary: €70M
#     📊 Avg Skill: 85.29 | 💰 Total Salary: €627M
#
# 🏆 Team 2
#   - GK: Jordan Smith | Skill: 88 | Salary: €100M
#   - DEF: Ethan Howard | Skill: 80 | Salary: €70M
#   - DEF: Caleb Fisher | Skill: 84 | Salary: €85M
#   - MID: Austin Torres | Skill: 82 | Salary: €80M
#   - MID: Dylan Morgan | Skill: 91 | Salary: €115M
#   - FWD: Elijah Sanders | Skill: 93 | Salary: €140M
#   - FWD: Julian Scott | Skill: 92 | Salary: €130M
#     📊 Avg Skill: 87.14 | 💰 Total Salary: €720M
#
# 🏆 Team 3
#   - GK: Chris Thompson | Skill: 80 | Salary: €80M
#   - DEF: Logan Brooks | Skill: 86 | Salary: €95M
#   - DEF: Maxwell Flores | Skill: 81 | Salary: €72M
#   - MID: Hunter Cooper | Skill: 83 | Salary: €85M
#   - MID: Connor Hayes | Skill: 89 | Salary: €105M
#   - FWD: Adrian Collins | Skill: 85 | Salary: €90M
#   - FWD: Colton Gray | Skill: 91 | Salary: €125M
#     📊 Avg Skill: 85.00 | 💰 Total Salary: €652M
#
# 🏆 Team 4
#   - GK: Ryan Mitchell | Skill: 83 | Salary: €85M
#   - DEF: Brayden Hughes | Skill: 87 | Salary: €100M
#   - DEF: Daniel Foster | Skill: 90 | Salary: €110M
#   - MID: Nathan Wright | Skill: 92 | Salary: €120M
#   - MID: Spencer Ward | Skill: 84 | Salary: €85M
#   - FWD: Chase Murphy | Skill: 86 | Salary: €95M
#   - FWD: Sebastian Perry | Skill: 95 | Salary: €150M
#     📊 Avg Skill: 88.14 | 💰 Total Salary: €745M
#
# 🏆 Team 5
#   - GK: Alex Carter | Skill: 85 | Salary: €90M
#   - DEF: Lucas Bennett | Skill: 85 | Salary: €90M
#   - DEF: Mason Reed | Skill: 82 | Salary: €75M
#   - MID: Dominic Bell | Skill: 86 | Salary: €95M
#   - MID: Bentley Rivera | Skill: 88 | Salary: €100M
#   - FWD: Xavier Bryant | Skill: 90 | Salary: €120M
#   - FWD: Landon Powell | Skill: 89 | Salary: €110M
#     📊 Avg Skill: 86.43 | 💰 Total Salary: €680M
#
# ✅ Valid League: True
#
# ==================================================
# 🏟️  Mutated League (Fitness: 1.1335)
# ==================================================
#
# 🏆 Team 1
#   - GK: Chris Thompson | Skill: 80 | Salary: €80M
#   - DEF: Owen Parker | Skill: 88 | Salary: €100M
#   - DEF: Jaxon Griffin | Skill: 79 | Salary: €65M
#   - MID: Gavin Richardson | Skill: 87 | Salary: €95M
#   - MID: Ashton Phillips | Skill: 90 | Salary: €110M
#   - FWD: Zachary Nelson | Skill: 86 | Salary: €92M
#   - FWD: Tyler Jenkins | Skill: 80 | Salary: €70M
#     📊 Avg Skill: 84.29 | 💰 Total Salary: €612M
#
# 🏆 Team 2
#   - GK: Alex Carter | Skill: 85 | Salary: €90M
#   - DEF: Brayden Hughes | Skill: 87 | Salary: €100M
#   - DEF: Caleb Fisher | Skill: 84 | Salary: €85M
#   - MID: Austin Torres | Skill: 82 | Salary: €80M
#   - MID: Dylan Morgan | Skill: 91 | Salary: €115M
#   - FWD: Elijah Sanders | Skill: 93 | Salary: €140M
#   - FWD: Julian Scott | Skill: 92 | Salary: €130M
#     📊 Avg Skill: 87.71 | 💰 Total Salary: €740M
#
# 🏆 Team 3
#   - GK: Jordan Smith | Skill: 88 | Salary: €100M
#   - DEF: Logan Brooks | Skill: 86 | Salary: €95M
#   - DEF: Maxwell Flores | Skill: 81 | Salary: €72M
#   - MID: Hunter Cooper | Skill: 83 | Salary: €85M
#   - MID: Connor Hayes | Skill: 89 | Salary: €105M
#   - FWD: Adrian Collins | Skill: 85 | Salary: €90M
#   - FWD: Sebastian Perry | Skill: 95 | Salary: €150M
#     📊 Avg Skill: 86.71 | 💰 Total Salary: €697M
#
# 🏆 Team 4
#   - GK: Ryan Mitchell | Skill: 83 | Salary: €85M
#   - DEF: Ethan Howard | Skill: 80 | Salary: €70M
#   - DEF: Daniel Foster | Skill: 90 | Salary: €110M
#   - MID: Nathan Wright | Skill: 92 | Salary: €120M
#   - MID: Spencer Ward | Skill: 84 | Salary: €85M
#   - FWD: Chase Murphy | Skill: 86 | Salary: €95M
#   - FWD: Colton Gray | Skill: 91 | Salary: €125M
#     📊 Avg Skill: 86.57 | 💰 Total Salary: €690M
#
# 🏆 Team 5
#   - GK: Blake Henderson | Skill: 87 | Salary: €95M
#   - DEF: Lucas Bennett | Skill: 85 | Salary: €90M
#   - DEF: Mason Reed | Skill: 82 | Salary: €75M
#   - MID: Dominic Bell | Skill: 86 | Salary: €95M
#   - MID: Bentley Rivera | Skill: 88 | Salary: €100M
#   - FWD: Xavier Bryant | Skill: 90 | Salary: €120M
#   - FWD: Landon Powell | Skill: 89 | Salary: €110M
#     📊 Avg Skill: 86.71 | 💰 Total Salary: €685M
#
# ✅ Valid League: True
# True

# %% [markdown]
# ## #2 Regenerate a Team Entirely

# %%
regenerate_team, success = mutation_regenerate_team(individual)
print(regenerate_team)
# Out:
# <LeagueIndividual fitness=0.9706>

# %%
if regenerate_team == individual:
    print("⚠️  No mutation applied (regenerate team failed).")
else:
    print("✅ Mutation applied successfully.")
# Out:
# ✅ Mutation applied successfully.

# %% [markdown]
# ### Testing code mutation_regenerate_team

# %%
def print_player_diff(orig_players, new_players):
    orig_names = set(p.name for p in orig_players)
    new_names = set(p.name for p in new_players)
    added = new_names - orig_names
    removed = orig_names - new_names
    return added, removed

def print_detailed_comparison(original, mutated):
    print(f"\n{'='*60}")
    print(f"🏟️  Regenerate Team Mutation Comparison")
    print(f"📈 Fitness: {original.fitness:.4f} → {mutated.fitness:.4f}")
    print(f"{'='*60}\n")

    # === First Pass: Determine the regenerated team ===
    max_changes = 0
    regenerated_team_index = None
    for i, (team_orig, team_mut) in enumerate(zip(original.league, mutated.league)):
        orig_names = set(p.name for p in team_orig.players)
        new_names = set(p.name for p in team_mut.players)
        changes = len(orig_names.symmetric_difference(new_names))
        if changes > max_changes:
            max_changes = changes
            regenerated_team_index = i

    # === Second Pass: Print teams ===
    for i, (team_orig, team_mut) in enumerate(zip(original.league, mutated.league)):
        team_label = f"🏆 Team {i+1}"
        if i == regenerated_team_index:
            team_label += " 🆕"
        print(f"\n{team_label}")
        print(f"Original Team:")
        for p in team_orig.players:
            print(f"  - {p}")
            print(f"    📊 Avg Skill: {team_orig.avg_skill():.2f} | 💰 Salary: €{team_orig.total_salary()}M")

        print(f"Mutated Team:")
        for p in team_mut.players:
            print(f"  - {p}")
        print(f"    📊 Avg Skill: {team_mut.avg_skill():.2f} | 💰 Salary: €{team_mut.total_salary()}M")

        added, removed = print_player_diff(team_orig.players, team_mut.players)
        if added or removed:
            print(f"    ➕ Added: {', '.join(added) if added else 'None'}")
            print(f"    ➖ Removed: {', '.join(removed) if removed else 'None'}")

    print(f"\n✅ League Valid: {all(team.is_valid(mutated.team_structure, mutated.budget_limit) for team in mutated.league)}")
    print(f"📌 Regenerated Team: Team {regenerated_team_index + 1 if regenerated_team_index is not None else 'Unknown'}")

# Example usage:
mutated, success = mutation_regenerate_team(individual)

if success:
    print_detailed_comparison(individual, mutated)
else:
    print("⚠️ Mutation failed (could not perform valid regeneration)")
# Out:
# ============================================================
# 🏟️  Regenerate Team Mutation Comparison
# 📈 Fitness: 1.1655 → 0.7080
# ============================================================
#
#
# 🏆 Team 1
# Original Team:
#   - GK: Blake Henderson | Skill: 87 | Salary: €95M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
#   - DEF: Owen Parker | Skill: 88 | Salary: €100M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
#   - DEF: Jaxon Griffin | Skill: 79 | Salary: €65M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
#   - MID: Gavin Richardson | Skill: 87 | Salary: €95M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
#   - MID: Ashton Phillips | Skill: 90 | Salary: €110M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
#   - FWD: Zachary Nelson | Skill: 86 | Salary: €92M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
#   - FWD: Tyler Jenkins | Skill: 80 | Salary: €70M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
# Mutated Team:
#   - GK: Blake Henderson | Skill: 87 | Salary: €95M
#   - DEF: Owen Parker | Skill: 88 | Salary: €100M
#   - MID: Gavin Richardson | Skill: 87 | Salary: €95M
#   - DEF: Maxwell Flores | Skill: 81 | Salary: €72M
#   - MID: Connor Hayes | Skill: 89 | Salary: €105M
#   - FWD: Colton Gray | Skill: 91 | Salary: €125M
#   - FWD: Adrian Collins | Skill: 85 | Salary: €90M
#     📊 Avg Skill: 86.86 | 💰 Salary: €682M
#     ➕ Added: Connor Hayes, Maxwell Flores, Adrian Collins, Colton Gray
#     ➖ Removed: Tyler Jenkins, Ashton Phillips, Jaxon Griffin, Zachary Nelson
#
# 🏆 Team 2
# Original Team:
#   - GK: Jordan Smith | Skill: 88 | Salary: €100M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
#   - DEF: Ethan Howard | Skill: 80 | Salary: €70M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
#   - DEF: Caleb Fisher | Skill: 84 | Salary: €85M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
#   - MID: Austin Torres | Skill: 82 | Salary: €80M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
#   - MID: Dylan Morgan | Skill: 91 | Salary: €115M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
#   - FWD: Elijah Sanders | Skill: 93 | Salary: €140M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
#   - FWD: Julian Scott | Skill: 92 | Salary: €130M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
# Mutated Team:
#   - DEF: Ethan Howard | Skill: 80 | Salary: €70M
#   - DEF: Caleb Fisher | Skill: 84 | Salary: €85M
#   - MID: Austin Torres | Skill: 82 | Salary: €80M
#   - MID: Dylan Morgan | Skill: 91 | Salary: €115M
#   - FWD: Elijah Sanders | Skill: 93 | Salary: €140M
#   - FWD: Julian Scott | Skill: 92 | Salary: €130M
#   - GK: Chris Thompson | Skill: 80 | Salary: €80M
#     📊 Avg Skill: 86.00 | 💰 Salary: €700M
#     ➕ Added: Chris Thompson
#     ➖ Removed: Jordan Smith
#
# 🏆 Team 3 🆕
# Original Team:
#   - GK: Chris Thompson | Skill: 80 | Salary: €80M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
#   - DEF: Logan Brooks | Skill: 86 | Salary: €95M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
#   - DEF: Maxwell Flores | Skill: 81 | Salary: €72M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
#   - MID: Hunter Cooper | Skill: 83 | Salary: €85M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
#   - MID: Connor Hayes | Skill: 89 | Salary: €105M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
#   - FWD: Adrian Collins | Skill: 85 | Salary: €90M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
#   - FWD: Colton Gray | Skill: 91 | Salary: €125M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
# Mutated Team:
#   - GK: Jordan Smith | Skill: 88 | Salary: €100M
#   - DEF: Jaxon Griffin | Skill: 79 | Salary: €65M
#   - DEF: Daniel Foster | Skill: 90 | Salary: €110M
#   - MID: Ashton Phillips | Skill: 90 | Salary: €110M
#   - MID: Bentley Rivera | Skill: 88 | Salary: €100M
#   - FWD: Zachary Nelson | Skill: 86 | Salary: €92M
#   - FWD: Tyler Jenkins | Skill: 80 | Salary: €70M
#     📊 Avg Skill: 85.86 | 💰 Salary: €647M
#     ➕ Added: Ashton Phillips, Daniel Foster, Tyler Jenkins, Jordan Smith, Jaxon Griffin, Bentley Rivera, Zachary Nelson
#     ➖ Removed: Chris Thompson, Connor Hayes, Colton Gray, Logan Brooks, Maxwell Flores, Hunter Cooper, Adrian Collins
#
# 🏆 Team 4
# Original Team:
#   - GK: Ryan Mitchell | Skill: 83 | Salary: €85M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
#   - DEF: Brayden Hughes | Skill: 87 | Salary: €100M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
#   - DEF: Daniel Foster | Skill: 90 | Salary: €110M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
#   - MID: Nathan Wright | Skill: 92 | Salary: €120M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
#   - MID: Spencer Ward | Skill: 84 | Salary: €85M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
#   - FWD: Chase Murphy | Skill: 86 | Salary: €95M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
#   - FWD: Sebastian Perry | Skill: 95 | Salary: €150M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
# Mutated Team:
#   - GK: Ryan Mitchell | Skill: 83 | Salary: €85M
#   - DEF: Brayden Hughes | Skill: 87 | Salary: €100M
#   - MID: Nathan Wright | Skill: 92 | Salary: €120M
#   - MID: Spencer Ward | Skill: 84 | Salary: €85M
#   - FWD: Chase Murphy | Skill: 86 | Salary: €95M
#   - FWD: Sebastian Perry | Skill: 95 | Salary: €150M
#   - DEF: Logan Brooks | Skill: 86 | Salary: €95M
#     📊 Avg Skill: 87.57 | 💰 Salary: €730M
#     ➕ Added: Logan Brooks
#     ➖ Removed: Daniel Foster
#
# 🏆 Team 5
# Original Team:
#   - GK: Alex Carter | Skill: 85 | Salary: €90M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
#   - DEF: Lucas Bennett | Skill: 85 | Salary: €90M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
#   - DEF: Mason Reed | Skill: 82 | Salary: €75M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
#   - MID: Dominic Bell | Skill: 86 | Salary: €95M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
#   - MID: Bentley Rivera | Skill: 88 | Salary: €100M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
#   - FWD: Xavier Bryant | Skill: 90 | Salary: €120M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
#   - FWD: Landon Powell | Skill: 89 | Salary: €110M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
# Mutated Team:
#   - GK: Alex Carter | Skill: 85 | Salary: €90M
#   - DEF: Lucas Bennett | Skill: 85 | Salary: €90M
#   - DEF: Mason Reed | Skill: 82 | Salary: €75M
#   - MID: Dominic Bell | Skill: 86 | Salary: €95M
#   - FWD: Xavier Bryant | Skill: 90 | Salary: €120M
#   - FWD: Landon Powell | Skill: 89 | Salary: €110M
#   - MID: Hunter Cooper | Skill: 83 | Salary: €85M
#     📊 Avg Skill: 85.71 | 💰 Salary: €665M
#     ➕ Added: Hunter Cooper
#     ➖ Removed: Bentley Rivera
#
# ✅ League Valid: True
# 📌 Regenerated Team: Team 3

# %% [markdown]
# ## #3 Balance Teams Average Skill (std dev)

# %%
third_mutation = mutation_balance_teams(individual)
print(third_mutation)
# Out:
# <LeagueIndividual fitness=0.6350>

# %%
if third_mutation == individual:
    print("⚠️  No mutation applied (swap failed after multiple attempts).")
else:
    print("✅ Mutation applied successfully.")
# Out:
# ✅ Mutation applied successfully.

# %% [markdown]
# ### Testing code mutation_balance_teams

# %%
def print_player_diff(orig_players, new_players):
    orig_names = set(p.name for p in orig_players)
    new_names = set(p.name for p in new_players)
    added = new_names - orig_names
    removed = orig_names - new_names
    return added, removed

def print_detailed_comparison(original, mutated):
    print(f"\n{'='*60}")
    print(f"🏟️  Mutation Comparison")
    print(f"📈 Fitness: {original.fitness:.4f} → {mutated.fitness:.4f}")
    print(f"{'='*60}\n")

    # Identify most-changed team
    max_changes = 0
    regenerated_team_index = None
    for i, (t1, t2) in enumerate(zip(original.league, mutated.league)):
        orig_names = set(p.name for p in t1.players)
        new_names = set(p.name for p in t2.players)
        changes = len(orig_names.symmetric_difference(new_names))
        if changes > max_changes:
            max_changes = changes
            regenerated_team_index = i

    # Print comparison
    for i, (t1, t2) in enumerate(zip(original.league, mutated.league)):
        team_label = f"🏆 Team {i+1}" + (" 🆕" if i == regenerated_team_index else "")
        print(f"\n{team_label}")
        print("Original Team:")
        for p in t1.players:
            print(f"  - {p}")
        print(f"    📊 Avg Skill: {t1.avg_skill():.2f} | 💰 Salary: €{t1.total_salary()}M")

        print("Mutated Team:")
        for p in t2.players:
            print(f"  - {p}")
        print(f"    📊 Avg Skill: {t2.avg_skill():.2f} | 💰 Salary: €{t2.total_salary()}M")

        added, removed = print_player_diff(t1.players, t2.players)
        if added or removed:
            print(f"    ➕ Added: {', '.join(added) if added else 'None'}")
            print(f"    ➖ Removed: {', '.join(removed) if removed else 'None'}")

    print(f"\n✅ League Valid: {all(t.is_valid(mutated.team_structure, mutated.budget_limit) for t in mutated.league)}")
    print(f"📌 Most changed team: Team {regenerated_team_index + 1 if regenerated_team_index is not None else 'Unknown'}")

# %%
def test_mutation_balance_teams():

    print("\n=== Testing: mutation_balance_teams ===")

    # Generate a sample individual
    mutated = mutation_balance_teams(individual)

    # Compare fitness
    print(f"\n📈 Original Fitness: {individual.fitness:.4f}")
    print(f"📉 Mutated Fitness:  {mutated.fitness:.4f}")

    # Identify changed teams
    changed_teams = []
    for i, (t1, t2) in enumerate(zip(individual.league, mutated.league)):
        if set(p.name for p in t1.players) != set(p.name for p in t2.players):
            changed_teams.append(i + 1)

    if mutated.fitness < individual.fitness:
        print("\n✅ Mutation successful! Fitness improved.")
    else:
        print("\n⚠️ No mutation applied. Fitness unchanged.")

    print(f"\n🔁 Changed team(s): {changed_teams if changed_teams else 'None'}")

    # Optionally, print detailed comparison
    print_detailed_comparison(individual, mutated)

# %%
test_mutation_balance_teams()
# Out:
# === Testing: mutation_balance_teams ===
#
# 📈 Original Fitness: 1.1655
# 📉 Mutated Fitness:  0.6154
#
# ✅ Mutation successful! Fitness improved.
#
# 🔁 Changed team(s): [3, 4]
#
# ============================================================
# 🏟️  Mutation Comparison
# 📈 Fitness: 1.1655 → 0.6154
# ============================================================
#
#
# 🏆 Team 1
# Original Team:
#   - GK: Blake Henderson | Skill: 87 | Salary: €95M
#   - DEF: Owen Parker | Skill: 88 | Salary: €100M
#   - DEF: Jaxon Griffin | Skill: 79 | Salary: €65M
#   - MID: Gavin Richardson | Skill: 87 | Salary: €95M
#   - MID: Ashton Phillips | Skill: 90 | Salary: €110M
#   - FWD: Zachary Nelson | Skill: 86 | Salary: €92M
#   - FWD: Tyler Jenkins | Skill: 80 | Salary: €70M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
# Mutated Team:
#   - GK: Blake Henderson | Skill: 87 | Salary: €95M
#   - DEF: Owen Parker | Skill: 88 | Salary: €100M
#   - DEF: Jaxon Griffin | Skill: 79 | Salary: €65M
#   - MID: Gavin Richardson | Skill: 87 | Salary: €95M
#   - MID: Ashton Phillips | Skill: 90 | Salary: €110M
#   - FWD: Zachary Nelson | Skill: 86 | Salary: €92M
#   - FWD: Tyler Jenkins | Skill: 80 | Salary: €70M
#     📊 Avg Skill: 85.29 | 💰 Salary: €627M
#
# 🏆 Team 2
# Original Team:
#   - GK: Jordan Smith | Skill: 88 | Salary: €100M
#   - DEF: Ethan Howard | Skill: 80 | Salary: €70M
#   - DEF: Caleb Fisher | Skill: 84 | Salary: €85M
#   - MID: Austin Torres | Skill: 82 | Salary: €80M
#   - MID: Dylan Morgan | Skill: 91 | Salary: €115M
#   - FWD: Elijah Sanders | Skill: 93 | Salary: €140M
#   - FWD: Julian Scott | Skill: 92 | Salary: €130M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
# Mutated Team:
#   - GK: Jordan Smith | Skill: 88 | Salary: €100M
#   - DEF: Ethan Howard | Skill: 80 | Salary: €70M
#   - DEF: Caleb Fisher | Skill: 84 | Salary: €85M
#   - MID: Austin Torres | Skill: 82 | Salary: €80M
#   - MID: Dylan Morgan | Skill: 91 | Salary: €115M
#   - FWD: Elijah Sanders | Skill: 93 | Salary: €140M
#   - FWD: Julian Scott | Skill: 92 | Salary: €130M
#     📊 Avg Skill: 87.14 | 💰 Salary: €720M
#
# 🏆 Team 3 🆕
# Original Team:
#   - GK: Chris Thompson | Skill: 80 | Salary: €80M
#   - DEF: Logan Brooks | Skill: 86 | Salary: €95M
#   - DEF: Maxwell Flores | Skill: 81 | Salary: €72M
#   - MID: Hunter Cooper | Skill: 83 | Salary: €85M
#   - MID: Connor Hayes | Skill: 89 | Salary: €105M
#   - FWD: Adrian Collins | Skill: 85 | Salary: €90M
#   - FWD: Colton Gray | Skill: 91 | Salary: €125M
#     📊 Avg Skill: 85.00 | 💰 Salary: €652M
# Mutated Team:
#   - GK: Chris Thompson | Skill: 80 | Salary: €80M
#   - DEF: Logan Brooks | Skill: 86 | Salary: €95M
#   - DEF: Maxwell Flores | Skill: 81 | Salary: €72M
#   - MID: Hunter Cooper | Skill: 83 | Salary: €85M
#   - MID: Connor Hayes | Skill: 89 | Salary: €105M
#   - FWD: Sebastian Perry | Skill: 95 | Salary: €150M
#   - FWD: Colton Gray | Skill: 91 | Salary: €125M
#     📊 Avg Skill: 86.43 | 💰 Salary: €712M
#     ➕ Added: Sebastian Perry
#     ➖ Removed: Adrian Collins
#
# 🏆 Team 4
# Original Team:
#   - GK: Ryan Mitchell | Skill: 83 | Salary: €85M
#   - DEF: Brayden Hughes | Skill: 87 | Salary: €100M
#   - DEF: Daniel Foster | Skill: 90 | Salary: €110M
#   - MID: Nathan Wright | Skill: 92 | Salary: €120M
#   - MID: Spencer Ward | Skill: 84 | Salary: €85M
#   - FWD: Chase Murphy | Skill: 86 | Salary: €95M
#   - FWD: Sebastian Perry | Skill: 95 | Salary: €150M
#     📊 Avg Skill: 88.14 | 💰 Salary: €745M
# Mutated Team:
#   - GK: Ryan Mitchell | Skill: 83 | Salary: €85M
#   - DEF: Brayden Hughes | Skill: 87 | Salary: €100M
#   - DEF: Daniel Foster | Skill: 90 | Salary: €110M
#   - MID: Nathan Wright | Skill: 92 | Salary: €120M
#   - MID: Spencer Ward | Skill: 84 | Salary: €85M
#   - FWD: Chase Murphy | Skill: 86 | Salary: €95M
#   - FWD: Adrian Collins | Skill: 85 | Salary: €90M
#     📊 Avg Skill: 86.71 | 💰 Salary: €685M
#     ➕ Added: Adrian Collins
#     ➖ Removed: Sebastian Perry
#
# 🏆 Team 5
# Original Team:
#   - GK: Alex Carter | Skill: 85 | Salary: €90M
#   - DEF: Lucas Bennett | Skill: 85 | Salary: €90M
#   - DEF: Mason Reed | Skill: 82 | Salary: €75M
#   - MID: Dominic Bell | Skill: 86 | Salary: €95M
#   - MID: Bentley Rivera | Skill: 88 | Salary: €100M
#   - FWD: Xavier Bryant | Skill: 90 | Salary: €120M
#   - FWD: Landon Powell | Skill: 89 | Salary: €110M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
# Mutated Team:
#   - GK: Alex Carter | Skill: 85 | Salary: €90M
#   - DEF: Lucas Bennett | Skill: 85 | Salary: €90M
#   - DEF: Mason Reed | Skill: 82 | Salary: €75M
#   - MID: Dominic Bell | Skill: 86 | Salary: €95M
#   - MID: Bentley Rivera | Skill: 88 | Salary: €100M
#   - FWD: Xavier Bryant | Skill: 90 | Salary: €120M
#   - FWD: Landon Powell | Skill: 89 | Salary: €110M
#     📊 Avg Skill: 86.43 | 💰 Salary: €680M
#
# ✅ League Valid: True
# 📌 Most changed team: Team 3

# %% [markdown]
# # Crossovers

# %%
# Generate Parents
parent1 = population[0]
parent2 = population[1]

# %% [markdown]
# ## #1 Crossover by Team

# %%
# Apply team crossover
child1_team, child2_team = team_crossover(parent1, parent2)

# %%
# Simple identity check
if child1_team == parent1 and child2_team == parent2:
    print("⚠️  No crossover effect — children are identical to parents.")
else:
    print("✅ Crossover applied successfully.")
# Out:
# ✅ Crossover applied successfully.

# %% [markdown]
# ### Testing code team_crossover

# %%
# === TEAM_CROSSOVER TESTING ===

# Pretty printer for LeagueIndividuals
def print_league(individual, label):
    print(f"\n{label} | 🧬 Fitness: {individual.fitness:.4f}")
    for i, team in enumerate(individual.league):
        print(f"🏆 Team {i+1}:")
        for p in team.players:
            print(f"    {p.name} ({p.position}) - 📊 Skill: {p.skill} - 💰 Salary: €{p.salary}M")


# Print parents and children
print_league(parent1, "👨 Parent 1")
print_league(parent2, "👩 Parent 2")
print_league(child1_team,  "🧒 Child 1 (Team Crossover)")
print_league(child2_team,  "🧒 Child 2 (Team Crossover)")
# Out:
# 👨 Parent 1 | 🧬 Fitness: 1.0317
# 🏆 Team 1:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
# 🏆 Team 2:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
# 🏆 Team 3:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M
# 🏆 Team 4:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
# 🏆 Team 5:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
#
# 👩 Parent 2 | 🧬 Fitness: 0.4815
# 🏆 Team 1:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
# 🏆 Team 2:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
# 🏆 Team 3:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
# 🏆 Team 4:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M
# 🏆 Team 5:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
#
# 🧒 Child 1 (Team Crossover) | 🧬 Fitness: 1.3774
# 🏆 Team 1:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
# 🏆 Team 2:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M
# 🏆 Team 3:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
# 🏆 Team 4:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
# 🏆 Team 5:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
#
# 🧒 Child 2 (Team Crossover) | 🧬 Fitness: 0.7897
# 🏆 Team 1:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
# 🏆 Team 2:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
# 🏆 Team 3:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
# 🏆 Team 4:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
# 🏆 Team 5:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M

# %% [markdown]
# ## #2 Crossover by Position

# %%
# Apply position crossover
child1_pos, child2_pos = position_crossover(parent1, parent2)

# %%
# Simple identity check
if child1_pos == parent1 and child2_pos == parent2:
    print("⚠️  No crossover effect — children are identical to parents.")
else:
    print("✅ Crossover applied successfully.")
# Out:
# ✅ Crossover applied successfully.

# %% [markdown]
# ### Testing code position_crossover

# %%
# === POSITION_CROSSOVER TESTING ===

# Pretty printer for LeagueIndividuals
def print_league(individual, label):
    print(f"\n{label} | 🧬 Fitness: {individual.fitness:.4f}")
    for i, team in enumerate(individual.league):
        print(f"🏆 Team {i+1}:")
        for p in team.players:
            print(f"    {p.name} ({p.position}) - 📊 Skill: {p.skill} - 💰 Salary: €{p.salary}M")

# Print detailed structure of both parents and children
print_league(parent1, "👨 Parent 1")
print_league(parent2, "👩 Parent 2")
print_league(child1_pos, "👶 Child 1 (Position Crossover)")
print_league(child2_pos, "👶 Child 2 (Position Crossover)")
# Out:
# 👨 Parent 1 | 🧬 Fitness: 1.0317
# 🏆 Team 1:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
# 🏆 Team 2:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
# 🏆 Team 3:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M
# 🏆 Team 4:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
# 🏆 Team 5:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
#
# 👩 Parent 2 | 🧬 Fitness: 0.4815
# 🏆 Team 1:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
# 🏆 Team 2:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
# 🏆 Team 3:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
# 🏆 Team 4:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M
# 🏆 Team 5:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
#
# 👶 Child 1 (Position Crossover) | 🧬 Fitness: 1.3862
# 🏆 Team 1:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
# 🏆 Team 2:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
# 🏆 Team 3:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M
# 🏆 Team 4:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
# 🏆 Team 5:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#
# 👶 Child 2 (Position Crossover) | 🧬 Fitness: 1.2854
# 🏆 Team 1:
#     Alex Carter (GK) - 📊 Skill: 85 - 💰 Salary: €90M
#     Owen Parker (DEF) - 📊 Skill: 88 - 💰 Salary: €100M
#     Jaxon Griffin (DEF) - 📊 Skill: 79 - 💰 Salary: €65M
#     Dominic Bell (MID) - 📊 Skill: 86 - 💰 Salary: €95M
#     Hunter Cooper (MID) - 📊 Skill: 83 - 💰 Salary: €85M
#     Adrian Collins (FWD) - 📊 Skill: 85 - 💰 Salary: €90M
#     Landon Powell (FWD) - 📊 Skill: 89 - 💰 Salary: €110M
# 🏆 Team 2:
#     Chris Thompson (GK) - 📊 Skill: 80 - 💰 Salary: €80M
#     Maxwell Flores (DEF) - 📊 Skill: 81 - 💰 Salary: €72M
#     Ethan Howard (DEF) - 📊 Skill: 80 - 💰 Salary: €70M
#     Spencer Ward (MID) - 📊 Skill: 84 - 💰 Salary: €85M
#     Gavin Richardson (MID) - 📊 Skill: 87 - 💰 Salary: €95M
#     Elijah Sanders (FWD) - 📊 Skill: 93 - 💰 Salary: €140M
#     Julian Scott (FWD) - 📊 Skill: 92 - 💰 Salary: €130M
# 🏆 Team 3:
#     Blake Henderson (GK) - 📊 Skill: 87 - 💰 Salary: €95M
#     Lucas Bennett (DEF) - 📊 Skill: 85 - 💰 Salary: €90M
#     Brayden Hughes (DEF) - 📊 Skill: 87 - 💰 Salary: €100M
#     Austin Torres (MID) - 📊 Skill: 82 - 💰 Salary: €80M
#     Ashton Phillips (MID) - 📊 Skill: 90 - 💰 Salary: €110M
#     Colton Gray (FWD) - 📊 Skill: 91 - 💰 Salary: €125M
#     Sebastian Perry (FWD) - 📊 Skill: 95 - 💰 Salary: €150M
# 🏆 Team 4:
#     Ryan Mitchell (GK) - 📊 Skill: 83 - 💰 Salary: €85M
#     Daniel Foster (DEF) - 📊 Skill: 90 - 💰 Salary: €110M
#     Mason Reed (DEF) - 📊 Skill: 82 - 💰 Salary: €75M
#     Dylan Morgan (MID) - 📊 Skill: 91 - 💰 Salary: €115M
#     Nathan Wright (MID) - 📊 Skill: 92 - 💰 Salary: €120M
#     Chase Murphy (FWD) - 📊 Skill: 86 - 💰 Salary: €95M
#     Xavier Bryant (FWD) - 📊 Skill: 90 - 💰 Salary: €120M
# 🏆 Team 5:
#     Jordan Smith (GK) - 📊 Skill: 88 - 💰 Salary: €100M
#     Logan Brooks (DEF) - 📊 Skill: 86 - 💰 Salary: €95M
#     Caleb Fisher (DEF) - 📊 Skill: 84 - 💰 Salary: €85M
#     Connor Hayes (MID) - 📊 Skill: 89 - 💰 Salary: €105M
#     Bentley Rivera (MID) - 📊 Skill: 88 - 💰 Salary: €100M
#     Zachary Nelson (FWD) - 📊 Skill: 86 - 💰 Salary: €92M
#     Tyler Jenkins (FWD) - 📊 Skill: 80 - 💰 Salary: €70M
